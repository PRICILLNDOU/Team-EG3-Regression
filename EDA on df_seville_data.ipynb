# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\ctair\\OneDrive\\Documents\\Explore AI Academy\\Machine Learning\\Predict Data\\df_train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
# 3           3  2015-01-01 12:00:00           1.000000           level_8
# 4           4  2015-01-01 15:00:00           1.000000           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
# 3             0.0             1.000000         65.333333        56.333333
# 4             0.0             1.000000         59.000000        57.000000
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Madrid_temp_max  Barcelona_temp  \
# ...

# %%
df.shape
# Out:
# (8763, 49)

# %%
#The shape command shows us that we have 8763 rows and 49 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8763 non-null   int64
#  1   time                  8763 non-null   object
#  2   Madrid_wind_speed     8763 non-null   float64
#  3   Valencia_wind_deg     8763 non-null   object
#  4   Bilbao_rain_1h        8763 non-null   float64
#  5   Valencia_wind_speed   8763 non-null   float64
#  6   Seville_humidity      8763 non-null   float64
#  7   Madrid_humidity       8763 non-null   float64
#  8   Bilbao_clouds_all     8763 non-null   float64
#  9   Bilbao_wind_speed     8763 non-null   float64
#  10  Seville_clouds_all    8763 non-null   float64
#  11  Bilbao_wind_deg       8763 non-null   float64
#  12  Barcelona_wind_speed  8763 non-null   float64
#  13  Barcelona_wind_deg    8763 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# time                       0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_pressure           0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Valencia_pressure       2068
# Seville_temp_max           0
# Madrid_pressure            0
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# count  8763.000000        8763.000000     8763.000000          8763.000000
# mean   4381.000000           2.425729        0.135753             2.586272
# std    2529.804538           1.850371        0.374901             2.411190
# min       0.000000           0.000000        0.000000             0.000000
# 25%    2190.500000           1.000000        0.000000             1.000000
# 50%    4381.000000           2.000000        0.000000             1.666667
# 75%    6571.500000           3.333333        0.100000             3.666667
# max    8762.000000          13.000000        3.000000            52.000000
#
#        Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# count       8763.000000      8763.000000        8763.000000
# mean          62.658793        57.414717          43.469132
# std           22.621226        24.335396          32.551044
# ...

# %%
Seville_Data = df.filter(like='Seville', axis=1)
print (Seville_Data)
# Out:
#       Seville_humidity  Seville_clouds_all  Seville_wind_speed  \
# 0            74.333333            0.000000            3.333333
# 1            78.333333            0.000000            3.333333
# 2            71.333333            0.000000            2.666667
# 3            65.333333            0.000000            4.000000
# 4            59.000000            0.000000            3.000000
# ...                ...                 ...                 ...
# 8758         89.000000           80.000000            1.000000
# 8759         82.000000           75.000000            1.666667
# 8760         67.666667           33.333333            3.666667
# 8761         67.666667           51.666667            4.333333
# 8762         78.666667           33.333333            1.666667
#
#      Seville_pressure  Seville_rain_1h  Seville_rain_3h  Seville_weather_id  \
# 0                sp25              0.0              0.0          800.000000
# ...

# %%
Seville_Summary = Seville_Data.describe()
print (Seville_Summary)
# Out:
#        Seville_humidity  Seville_clouds_all  Seville_wind_speed  \
# count       8763.000000         8763.000000         8763.000000
# mean          62.658793           13.714748            2.425045
# std           22.621226           24.272482            1.672895
# min            8.333333            0.000000            0.000000
# 25%           44.333333            0.000000            1.000000
# 50%           65.666667            0.000000            2.000000
# 75%           82.000000           20.000000            3.333333
# max          100.000000           97.333333           11.666667
#
#        Seville_rain_1h  Seville_rain_3h  Seville_weather_id  Seville_temp_max  \
# count      8763.000000      8763.000000         8763.000000       8763.000000
# mean          0.039439         0.000243          774.658818        297.479527
# std           0.175857         0.003660           71.940009          8.875812
# ...

# %%
df.skew()
# Out:
# Unnamed: 0               0.000000
# Madrid_wind_speed        1.441144
# Bilbao_rain_1h           5.222802
# Valencia_wind_speed      3.499637
# Seville_humidity        -0.310175
# Madrid_humidity         -0.057378
# Bilbao_clouds_all       -0.053085
# Bilbao_wind_speed        1.716914
# Seville_clouds_all       1.814452
# Bilbao_wind_deg          0.226927
# Barcelona_wind_speed     1.057331
# Barcelona_wind_deg      -0.180001
# Madrid_clouds_all        1.246745
# Seville_wind_speed       1.151006
# Barcelona_rain_1h        8.726988
# Seville_rain_1h          8.067341
# Bilbao_snow_3h          26.177568
# Barcelona_pressure      57.979664
# Seville_rain_3h         19.342574
# Madrid_rain_1h           7.074308
# Barcelona_rain_3h       12.696605
# Valencia_snow_3h        63.298084
# Madrid_weather_id       -3.107722
# Barcelona_weather_id    -2.584011
# Bilbao_pressure         -0.999642
# Seville_weather_id      -3.275574
# Valencia_pressure       -1.705162
# ...

# %%
df.kurtosis()
# Out:
# Unnamed: 0                -1.200000
# Madrid_wind_speed          2.036462
# Bilbao_rain_1h            32.904656
# Valencia_wind_speed       35.645426
# Seville_humidity          -1.017983
# Madrid_humidity           -1.167537
# Bilbao_clouds_all         -1.533417
# Bilbao_wind_speed          3.631565
# Seville_clouds_all         2.155921
# Bilbao_wind_deg           -1.083530
# Barcelona_wind_speed       1.493635
# Barcelona_wind_deg        -0.959160
# Madrid_clouds_all          0.142079
# Seville_wind_speed         1.398580
# Barcelona_rain_1h        101.578931
# Seville_rain_1h           93.840746
# Bilbao_snow_3h           806.128471
# Barcelona_pressure      3687.564230
# Seville_rain_3h          413.136592
# Madrid_rain_1h            76.584491
# Barcelona_rain_3h        187.800460
# Valencia_snow_3h        4089.323165
# Madrid_weather_id          9.259047
# Barcelona_weather_id       5.701882
# Bilbao_pressure            1.825323
# Seville_weather_id        10.710308
# ...

# %%
features = ['Seville_humidity', 'Seville_clouds_all', 'Seville_wind_speed', 'Seville_rain_1h', 'Seville_rain_3h', 'Seville_weather_id', 'Seville_temp','Seville_temp_min', 'Seville_temp_max'] # create a list of all numerical features
df[features].hist(figsize=(10,10));

# %%
sns.boxplot(x='Seville_temp', data=df);

# %%
sns.countplot(x ='Seville_wind_speed', data = df, palette="hls")
plt.title("Seville Wind Speed");

# %%
sns.countplot(x ='Seville_rain_1h', data = df, palette="hls")
plt.title("Seville Rain after 1 Hour");

# %%
# The columns for which to find correlation coefficients

columns_to_correlate = ['Seville_humidity', 'Seville_clouds_all', 'Seville_wind_speed', 'Seville_rain_1h', 'Seville_rain_3h', 'Seville_weather_id', 'Seville_temp','Seville_temp_min', 'Seville_temp_max']

# Calculate the correlation coefficients for the selected columns
correlation_matrix = df[columns_to_correlate].corr()

# Print the correlation coefficients
print("Correlation Coefficients for Seville Data:")
print(correlation_matrix)
# Out:
# Correlation Coefficients for Seville Data:
#                     Seville_humidity  Seville_clouds_all  Seville_wind_speed  \
# Seville_humidity            1.000000            0.399436           -0.202449
# Seville_clouds_all          0.399436            1.000000            0.144119
# Seville_wind_speed         -0.202449            0.144119            1.000000
# Seville_rain_1h             0.227476            0.408001            0.125560
# Seville_rain_3h             0.034343            0.087240            0.001149
# Seville_weather_id         -0.328265           -0.537924           -0.143958
# Seville_temp               -0.743126           -0.208859            0.139573
# Seville_temp_min           -0.784850           -0.200453            0.154254
# Seville_temp_max           -0.566426           -0.181783            0.096339
#
#                     Seville_rain_1h  Seville_rain_3h  Seville_weather_id  \
# Seville_humidity           0.227476         0.034343           -0.328265
# ...

# %%
columns_to_correlate = ['Seville_humidity', 'Seville_clouds_all', 'Seville_wind_speed', 'Seville_rain_1h', 'Seville_rain_3h', 'Seville_weather_id', 'Seville_temp','Seville_temp_min', 'Seville_temp_max']

# Compute the correlation matrix
correlation_matrix = Seville_Data[columns_to_correlate].corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', annot_kws={"size": 10})
plt.title('Correlation Matrix HeatMap for Seville Data')
plt.show()

# %%
# The joint plot will be used to provide univariate and multivariate analyses at the same time. 
# For this joint plot, we will compare Seville Humidity and Seville Clouds Average.

sns.jointplot(x = 'Seville_humidity', y = 'Seville_clouds_all', data = df);
